# %% [markdown]
# ## EDA using Pandas Group By

# %% [markdown]
# #### Group by is applicable in three steps process:
# * Splitting the data
# * Applying conditin/function
# * Combining the results

# %%
## This comes under feature engineering

# %%
import pandas as pd
import numpy as np

# %%
dfgen = pd.read_csv("Gb_gender.csv")
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
# Finding the tallest people in the male and female groups

# %%
# Split the data using "Gender"
dfgen["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
gbgen = dfgen.groupby("Gender")
gbgen

# %%
gbgen.groups
# Out:
# {'Female': [1, 2, 6, 7, 8, 10, 12, 13, 17, 18, 19, 21, 22, 28, 29, 30, 32, 34, 35, 39, 40, 41, 42, 44, 46, 47, 51, 52, 53, 55, 56, 62, 63, 64, 66, 68, 70, 71, 73, 75, 76, 78], 'Male': [0, 3, 4, 5, 9, 11, 14, 15, 16, 20, 23, 24, 25, 26, 27, 31, 33, 36, 37, 38, 43, 45, 48, 49, 50, 54, 57, 58, 59, 60, 61, 65, 67, 69, 72, 74, 77, 79, 80]}

# %%
dfgen.head()
# Out:
#    Gender  Degree  Height       City
# 0    Male    B.Sc     174  Hyderabad
# 1  Female  B.Tech     167    Chennai
# 2  Female     B.E     169      Vizag
# 3    Male   B.Com     173      Delhi
# 4    Male     MBA     177     Jaipur

# %%
gbgen.head()
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 1  Female  B.Tech     167     Chennai
# 2  Female     B.E     169       Vizag
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 6  Female  M.Tech     172     Lucknow
# 7  Female     MCA     172      Bhopal
# 8  Female    B.Sc     179   Bangalore
# 9    Male  B.Tech     166   Hyderabad

# %%
for x , y in gbgen:
    print(x)
    print()
    print(y)
    print()
    print("**************************")
    print()
# Out:
# Female
#
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
# Finding the tallest male and tallest female

# %%
dffemale = gbgen.get_group("Female")
dffemale
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
dffemale.shape
# Out:
# (42, 4)

# %%
# Applying function

dffemale["Height"].max()
# Out:
# 179

# %%
# how many people having 179 height?
dffemale["Height"] == dffemale["Height"].max()
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
# Result

fres = dffemale[dffemale["Height"] == dffemale["Height"].max()]
fres
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag

# %%
dfmale = gbgen.get_group("Male")
dfmale
# Out:
#    Gender  Degree  Height        City
# 0    Male    B.Sc     174   Hyderabad
# 3    Male   B.Com     173       Delhi
# 4    Male     MBA     177      Jaipur
# 5    Male    M.Sc     178  Chandigarh
# 9    Male  B.Tech     166   Hyderabad
# 11   Male   B.Com     176       Vizag
# 14   Male  M.Tech     166  Chandigarh
# 15   Male     MCA     175     Lucknow
# 16   Male   B.Com     166      Bhopal
# 20   Male     MCA     171  Chandigarh
# 23   Male     B.E     173   Bangalore
# 24   Male   B.Com     175   Hyderabad
# 25   Male   B.Com     173       Delhi
# 26   Male     MBA     177      Jaipur
# 27   Male    M.Sc     178  Chandigarh
# 31   Male  B.Tech     173   Hyderabad
# 33   Male   B.Com     174       Vizag
# 36   Male  M.Tech     175  Chandigarh
# 37   Male     MCA     166     Lucknow
# 38   Male   B.Com     178      Bhopal
# 43   Male  B.Tech     177     Lucknow
# 45   Male   B.Com     172   Bangalore
# 48   Male  M.Tech     166      Jaipur
# 49   Male     MCA     173  Chandigarh
# ...

# %%
# Applying function

dfmale["Height"].max()
# Out:
# 178

# %%
# Result

mres = dfmale[dfmale["Height"] == dfmale["Height"].max()]
mres
# Out:
#    Gender Degree  Height        City
# 5    Male   M.Sc     178  Chandigarh
# 27   Male   M.Sc     178  Chandigarh
# 38   Male  B.Com     178      Bhopal
# 72   Male  B.Com     178      Jaipur
# 74   Male   M.Sc     178       Vizag
# 77   Male    MCA     178     Chennai

# %%
# Combining the results

results = pd.concat([fres, mres])
results
# Out:
#     Gender  Degree  Height        City
# 8   Female    B.Sc     179   Bangalore
# 47  Female    M.Sc     179       Delhi
# 70  Female  M.Tech     179   Hyderabad
# 73  Female     MBA     179      Bhopal
# 75  Female  M.Tech     179       Vizag
# 5     Male    M.Sc     178  Chandigarh
# 27    Male    M.Sc     178  Chandigarh
# 38    Male   B.Com     178      Bhopal
# 72    Male   B.Com     178      Jaipur
# 74    Male    M.Sc     178       Vizag
# 77    Male     MCA     178     Chennai

# %%
# Similarly we can split the data using two columns

gbgen2 = dfgen.groupby(["Gender", "City"])
gbgen2

# %%
for x , y in gbgen2:
    print(x)
    print()
    print(y)
    print("********************************")
    print()
# Out:
# ('Female', 'Bangalore')
#
#     Gender Degree  Height       City
# 8   Female   B.Sc     179  Bangalore
# 30  Female   B.Sc     166  Bangalore
# 52  Female   M.Sc     168  Bangalore
# ********************************
#
# ('Female', 'Bhopal')
#
#     Gender  Degree  Height    City
# 7   Female     MCA     172  Bhopal
# 22  Female  B.Tech     167  Bhopal
# 29  Female     MCA     172  Bhopal
# 44  Female     B.E     178  Bhopal
# 51  Female     MBA     174  Bhopal
# 73  Female     MBA     179  Bhopal
# ********************************
#
# ('Female', 'Chandigarh')
#
#     Gender Degree  Height        City
# 42  Female   B.Sc     173  Chandigarh
# 63  Female    MCA     175  Chandigarh
# ********************************
#
# ('Female', 'Chennai')
#
#     Gender  Degree  Height     City
# 1   Female  B.Tech     167  Chennai
# 10  Female     B.E     173  Chennai
# 32  Female     B.E     176  Chennai
# ********************************
#
# ('Female', 'Delhi')
#
# ...

# %%
gbgen2.get_group(("Female" , "Hyderabad"))
# Out:
#     Gender  Degree  Height       City
# 46  Female     MBA     172  Hyderabad
# 53  Female  M.Tech     166  Hyderabad
# 66  Female     B.E     178  Hyderabad
# 68  Female     MBA     172  Hyderabad
# 70  Female  M.Tech     179  Hyderabad
# 76  Female    B.Sc     176  Hyderabad
# 78  Female    B.Sc     178  Hyderabad

# %% [markdown]
# ### Without Using GroupBy

# %%
dfgen
# Out:
#     Gender  Degree  Height        City
# 0     Male    B.Sc     174   Hyderabad
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 3     Male   B.Com     173       Delhi
# 4     Male     MBA     177      Jaipur
# ..     ...     ...     ...         ...
# 76  Female    B.Sc     176   Hyderabad
# 77    Male     MCA     178     Chennai
# 78  Female    B.Sc     178   Hyderabad
# 79    Male  B.Tech     174  Chandigarh
# 80    Male  M.Tech     175     Lucknow
#
# [81 rows x 4 columns]

# %%
dfgen["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dfgen["Gender"].nunique()
# Out:
# 2

# %%
dfgen["Degree"].unique()
# Out:
# array(['B.Sc', 'B.Tech', 'B.E', 'B.Com', 'MBA', 'M.Sc', 'M.Tech', 'MCA'],
#       dtype=object)

# %%
dfgen["Degree"].nunique()
# Out:
# 8

# %%
dfgen['City'].unique()
# Out:
# array(['Hyderabad', 'Chennai', 'Vizag', 'Delhi', 'Jaipur', 'Chandigarh',
#        'Lucknow', 'Bhopal', 'Bangalore'], dtype=object)

# %%
dfgen['City'].nunique()
# Out:
# 9

# %%
dfgen["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dfgen["Gender"].value_counts()
# Out:
# Female    42
# Male      39
# Name: Gender, dtype: int64

# %%
dfgen["Gender"].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
dfgen[dfgen['Gender'] == 'Female']
# Out:
#     Gender  Degree  Height        City
# 1   Female  B.Tech     167     Chennai
# 2   Female     B.E     169       Vizag
# 6   Female  M.Tech     172     Lucknow
# 7   Female     MCA     172      Bhopal
# 8   Female    B.Sc     179   Bangalore
# 10  Female     B.E     173     Chennai
# 12  Female     MBA     174       Delhi
# 13  Female    M.Sc     168      Jaipur
# 17  Female     MBA     178       Vizag
# 18  Female    M.Sc     175       Delhi
# 19  Female  M.Tech     177      Jaipur
# 21  Female    B.Sc     171     Lucknow
# 22  Female  B.Tech     167      Bhopal
# 28  Female  M.Tech     172     Lucknow
# 29  Female     MCA     172      Bhopal
# 30  Female    B.Sc     166   Bangalore
# 32  Female     B.E     176     Chennai
# 34  Female     MBA     168       Delhi
# 35  Female    M.Sc     166      Jaipur
# 39  Female     MBA     175       Vizag
# 40  Female    M.Sc     177       Delhi
# 41  Female  M.Tech     171      Jaipur
# 42  Female    B.Sc     173  Chandigarh
# ...

# %%
dfgen[dfgen['Gender'] == 'Female']["Height"].max()
# Out:
# 179

# %%
dfgen[dfgen['Gender'] == 'Female']["Height"] == dfgen[dfgen['Gender'] == 'Female']["Height"].max()
# Out:
# 1     False
# 2     False
# 6     False
# 7     False
# 8      True
# 10    False
# 12    False
# 13    False
# 17    False
# 18    False
# 19    False
# 21    False
# 22    False
# 28    False
# 29    False
# 30    False
# 32    False
# 34    False
# 35    False
# 39    False
# 40    False
# 41    False
# 42    False
# 44    False
# 46    False
# 47     True
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 62    False
# 63    False
# 64    False
# 66    False
# 68    False
# 70     True
# 71    False
# 73     True
# 75     True
# 76    False
# 78    False
# Name: Height, dtype: bool

# %%
dfgen[dfgen['Gender'] == 'Female'][dfgen[dfgen['Gender'] == 'Female']["Height"] == dfgen[dfgen['Gender'] == 'Female']["Height"].max()]
# Out:
#     Gender  Degree  Height       City
# 8   Female    B.Sc     179  Bangalore
# 47  Female    M.Sc     179      Delhi
# 70  Female  M.Tech     179  Hyderabad
# 73  Female     MBA     179     Bhopal
# 75  Female  M.Tech     179      Vizag
